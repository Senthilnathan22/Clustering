# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X=dataset.iloc[:, [3,4]].values

# %%
X.shape
# Out:
# (200, 2)

# %%
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
X_labels = make_blobs(n_samples=200, centers=5, random_state=42)
mean_shift = MeanShift()
mean_shift.fit(X)
plt.scatter(X[:, 0], X[:, 1], c=mean_shift.labels_, cmap='viridis', marker='o')
plt.scatter(mean_shift.cluster_centers_[:, 0], mean_shift.cluster_centers_[:, 1], 
            c='red', marker='x', s=200, linewidths=3, label='Cluster Centers')
plt.title('Mean Shift Clustering')
plt.xlabel('salary')
plt.ylabel('Spending')
plt.legend()
plt.show()
# Out:
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# ...

# %%
from sklearn.cluster import MeanShift
meanshift=MeanShift(bandwidth=5, seeds=None, bin_seeding=False,)
y_mean=meanshift.fit_predict(X)
# Out:
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# ...

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=y_mean

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0               37
# 1               10
# 2               23
# ...

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5],
                 fit_reg=False,legend=True, legend_out=True)
# Out:
# C:\Users\Bagirathan\anaconda3\envs\GenAI\lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
